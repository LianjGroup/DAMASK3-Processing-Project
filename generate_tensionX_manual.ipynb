# %%
import numpy as np
import damask

import os
from math import * 
os.getcwd()
print("The current directory is: ")
print(os.getcwd())
# Out:
# The current directory is:
# c:\Users\springnuance\Desktop\DAMASK3-Processing-Project
# Moving up to the parent directory
# c:\Users\springnuance\Desktop

# %%
def inversion(l,fill=0):
    return [inversion(i,fill) if isinstance(i,list) else\
            fill if i == 'x' else 'x' for i in l]

load_case = damask.Config(solver={'mechanical':'spectral_basic'},
                          loadstep=[])

# %%
F = [[1.05, 0 , 0 ],
     [   0,'x', 0 ],
     [   0, 0 ,'x']]

loadstep = {'boundary_conditions':{'mechanical':{'F':F,
                                                 'P':inversion(F)}},
                                   'discretization':{'t':10.,'N':40},'f_out':4}
load_case['loadstep'].append(loadstep)

dot_P = [[ 0 ,'x','x'],
         ['x','x','x'],
         ['x','x','x']]

loadstep = {'boundary_conditions':{'mechanical':{'dot_P':dot_P,
                                                 'dot_F':inversion(dot_P)}},
                                   'discretization':{'t':10.,'N':20}}
load_case['loadstep'].append(loadstep)

P = [[ 0 ,'x','x'],
     ['x', 0 ,'x'],
     ['x','x', 0 ]]

loadstep = {'boundary_conditions':{'mechanical':{'P':P,
                                                 'dot_F':inversion(P)}},
                                   'discretization':{'t':10.,'N':20}}
load_case['loadstep'].append(loadstep)

load_case.save('tension-hold-unload.yaml')
load_case
# Out:
# solver: {mechanical: spectral_basic}
#
# loadstep:
#   - boundary_conditions:
#       mechanical:
#         F:
#           - [1.05, 0, 0]
#           - [0, x, 0]
#           - [0, 0, x]
#         P:
#           - [x, x, x]
#           - [x, 0, x]
#           - [x, x, 0]
#     discretization: {t: 10.0, N: 40}
#     f_out: 4
#   - boundary_conditions:
#       mechanical:
#         dot_P:
#           - [0, x, x]
#           - [x, x, x]
#           - [x, x, x]
#         dot_F:
#           - [x, 0, 0]
#           - [0, 0, 0]
#           - [0, 0, 0]
#     discretization: {t: 10.0, N: 20}
#   - boundary_conditions:
#       mechanical:
#         P:
#           - [0, x, x]
#           - [x, 0, x]
#           - [x, x, 0]
#         dot_F:
#           - [x, 0, 0]
#           - [0, x, 0]
#           - [0, 0, x]
#     discretization: {t: 10.0, N: 20}

# %%
loading_paths = [
    "PH_linear_uniaxial_RD",
    "PH_linear_uniaxial_TD",
    "PH_nonlinear_biaxial_RD",
    "PH_nonlinear_biaxial_TD",
    "PH_nonlinear_planestrain_RD",
    "PH_nonlinear_planestrain_TD",
    "PH_nonlinear_uniaxial_RD",
    "PH_nonlinear_uniaxial_TD",
    "DB_linear_uniaxial_RD",
    "DB_linear_uniaxial_TD",
    "DB_nonlinear_biaxial_RD",
    "DB_nonlinear_biaxial_TD",
    "DB_nonlinear_planestrain_RD",
    "DB_nonlinear_planestrain_TD",
    "DB_nonlinear_uniaxial_RD",
    "DB_nonlinear_uniaxial_TD",
]

# %% [markdown]
# linear_uniaxial_RD

# %%
tensionX = damask.Config("""
---

solver:
  mechanical: spectral_basic

loadstep:
  - boundary_conditions:
      mechanical:
        dot_F: [[x, 0, 0],
                [0, 1.0e-4, 0],
                [0, 0, x]]
        P: [[0, x, x],
            [x, x, x],
            [x, x, 0]]
    discretization:
      t: 40
      N: 20
    f_out: 2
  - boundary_conditions:
      mechanical:
        dot_F: [[x, 0, 0],
                [0, 1.0e-4, 0],
                [0, 0, x]]
        P: [[0, x, x],
            [x, x, x],
            [x, x, 0]]
    discretization:
      t: 130
      N: 20
    f_out: 4
  - boundary_conditions:
      mechanical:
        dot_F: [[x, 0, 0],
                [0, 1.0e-4, 0],
                [0, 0, x]]
        P: [[0, x, x],
            [x, x, x],
            [x, x, 0]]
    discretization:
      t: 1550
      N: 80
    f_out: 4
  - boundary_conditions:
      mechanical:
        dot_F: [[x, 0, 0],
                [0, 1.0e-4, 0],
                [0, 0, x]]
        P: [[0, x, x],
            [x, x, x],
            [x, x, 0]]
    discretization:
      t: 300
      N: 20
    f_out: 4

""")

tensionX.save(f"damask3/templates/PH_linear_uniaxial_RD/tensionX.yaml")
tensionX.save(f"damask3/templates/DB_linear_uniaxial_RD/tensionX.yaml")

tensionLoad = '''
              fdot * 0 0  0 1e-4 0   0 0 *  stress  0 * *   * * *   * * 0  time 40  incs 20 freq 2       
              fdot * 0 0  0 1e-4 0   0 0 *  stress  0 * *   * * *   * * 0  time 130  incs 20 freq 4
              fdot * 0 0  0 1e-4 0   0 0 *  stress  0 * *   * * *   * * 0  time 1550  incs 80 freq 4     
              fdot * 0 0  0 1e-4 0   0 0 *  stress  0 * *   * * *   * * 0  time 300  incs 20 freq 4 
              '''
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 59
#       1 tensionX = damask.Config("""
#       2 ---
#       3
#    (...)
#      56
#      57 """)
# ---> 59 tensionX.save(f"damask3/templates/PH_linear_uniaxial_RD/tensionX.yaml")
#      60 tensionX.save(f"damask3/templates/DB_linear_uniaxial_RD/tensionX.yaml")
#      62 tensionLoad = '''
#      63               fdot * 0 0  0 1e-4 0   0 0 *  stress  0 * *   * * *   * * 0  time 40  incs 20 freq 2
#      64               fdot * 0 0  0 1e-4 0   0 0 *  stress  0 * *   * * *   * * 0  time 130  incs 20 freq 4
#      65               fdot * 0 0  0 1e-4 0   0 0 *  stress  0 * *   * * *   * * 0  time 1550  incs 80 freq 4
#      66               fdot * 0 0  0 1e-4 0   0 0 *  stress  0 * *   * * *   * * 0  time 300  incs 20 freq 4
#      67               '''
#
# ...

# %% [markdown]
# linear_uniaxial_TD

# %%
tensionX = damask.Config("""
---

solver:
  mechanical: spectral_basic

loadstep:
  - boundary_conditions:
      mechanical:
        dot_F: [[1.0e-4, 0, 0],
                [0, x, 0],
                [0, 0, x]]
        P: [[x, x, x],
            [x, 0, x],
            [x, x, 0]]
    discretization:
      t: 40
      N: 20
    f_out: 2
  - boundary_conditions:
      mechanical:
        dot_F: [[1.0e-4, 0, 0],
                [0, x, 0],
                [0, 0, x]]
        P: [[x, x, x],
            [x, 0, x],
            [x, x, 0]]
    discretization:
      t: 130
      N: 20
    f_out: 4
  - boundary_conditions:
      mechanical:
        dot_F: [[1.0e-4, 0, 0],
                [0, x, 0],
                [0, 0, x]]
        P: [[x, x, x],
            [x, 0, x],
            [x, x, 0]]
    discretization:
      t: 1550
      N: 80
    f_out: 4
  - boundary_conditions:
      mechanical:
        dot_F: [[1.0e-4, 0, 0],
                [0, x, 0],
                [0, 0, x]]
        P: [[x, x, x],
            [x, 0, x],
            [x, x, 0]]
    discretization:
      t: 300
      N: 20
    f_out: 4

""")

tensionX.save(f"damask3/templates/PH_linear_uniaxial_TD/tensionX.yaml")
tensionX.save(f"damask3/templates/DB_linear_uniaxial_TD/tensionX.yaml")

tensionLoad = '''
              fdot 1e-4 0 0  0 * 0   0 0 *  stress  * * *   * 0 *   * * 0  time 40  incs 20 freq 2       
              fdot 1e-4 0 0  0 * 0   0 0 *  stress  * * *   * 0 *   * * 0  time 130  incs 20 freq 4
              fdot 1e-4 0 0  0 * 0   0 0 *  stress  * * *   * 0 *   * * 0  time 1550  incs 80 freq 4     
              fdot 1e-4 0 0  0 * 0   0 0 *  stress  * * *   * 0 *   * * 0  time 300  incs 20 freq 4 
              '''

# %% [markdown]
# nonlinear_biaxial_RD

# %%
tensionX = damask.Config("""
solver:
  mechanical: spectral_basic

loadstep:
  - discretization:
      t: 60
      N: 80
    f_out: 4
    boundary_conditions:
      mechanical:
        dot_F: [[4.75e-5, 0, 0],
                [0, 5.25e-5, 0],
                [0, 0, x]]
        P: [[x, x, x],
            [x, x, x],
            [x, x, 0]]
  - discretization:
      t: 1140
      N: 80
    f_out: 4
    boundary_conditions:
      mechanical:
        dot_F: [[4.75e-5, 0, 0],
                [0, 5.25e-5, 0],
                [0, 0, x]]
        P: [[x, x, x],
            [x, x, x],
            [x, x, 0]]
  - discretization:
      t: 44
      N: 80
    f_out: 4
    boundary_conditions:
      mechanical:
        dot_F: [[-4.75e-5, 0, 0],
                [0, -5.25e-5, 0],
                [0, 0, x]]
        P: [[x, x, x],
            [x, x, x],
            [x, x, 0]]
  - discretization:
      t: 78
      N: 80
    f_out: 4
    boundary_conditions:
      mechanical:
        dot_F: [[x, 0, 0],
                [0, 1.0e-4, 0],
                [0, 0, x]]
        P: [[0, x, x],
            [x, x, x],
            [x, x, 0]]
  - discretization:
      t: 1518
      N: 80
    f_out: 4
    boundary_conditions:
      mechanical:
        dot_F: [[x, 0, 0],
                [0, 1.0e-4, 0],
                [0, 0, x]]
        P: [[0, x, x],
            [x, x, x],
            [x, x, 0]]
""")

tensionX.save(f"damask3/templates/PH_nonlinear_biaxial_RD/tensionX.yaml")
tensionX.save(f"damask3/templates/DB_nonlinear_biaxial_RD/tensionX.yaml")

tensionLoad = '''
              fdot 4.75e-5 0 0  0 5.25e-5 0   0 0 *  stress  * * *   * * *   * * 0  time 60  incs 80 freq 4
              fdot 4.75e-5 0 0  0 5.25e-5 0   0 0 *  stress  * * *   * * *   * * 0  time 1140  incs 80 freq 4
              fdot -4.75e-5 0 0  0 -5.25e-5 0   0 0 *  stress  * * *   * * *   * * 0  time 44  incs 80 freq 4
              fdot * 0 0  0 1e-4 0   0 0 *  stress  0 * *   * * *   * * 0  time 78  incs 80 freq 4
              fdot * 0 0  0 1e-4 0   0 0 *  stress  0 * *   * * *   * * 0  time 1518  incs 80 freq 4
              '''

# %% [markdown]
# nonlinear_biaxial_TD

# %%
tensionX = damask.Config("""
solver:
  mechanical: spectral_basic

loadstep:
  - discretization:
      t: 60
      N: 80
    f_out: 4
    boundary_conditions:
      mechanical:
        dot_F: [[4.75e-5, 0, 0],
                [0, 5.25e-5, 0],
                [0, 0, x]]
        P: [[x, x, x],
            [x, x, x],
            [x, x, 0]]
  - discretization:
      t: 1140
      N: 80
    f_out: 4
    boundary_conditions:
      mechanical:
        dot_F: [[4.75e-5, 0, 0],
                [0, 5.25e-5, 0],
                [0, 0, x]]
        P: [[x, x, x],
            [x, x, x],
            [x, x, 0]]
  - discretization:
      t: 44
      N: 80
    f_out: 4
    boundary_conditions:
      mechanical:
        dot_F: [[-4.75e-5, 0, 0],
                [0, -5.25e-5, 0],
                [0, 0, x]]
        P: [[x, x, x],
            [x, x, x],
            [x, x, 0]]
  - discretization:
      t: 78
      N: 80
    f_out: 4
    boundary_conditions:
      mechanical:
        dot_F: [[1e-4, 0, 0],
                [0, x, 0],
                [0, 0, x]]
        P: [[x, x, x],
            [x, 0, x],
            [x, x, 0]]
  - discretization:
      t: 1518
      N: 80
    f_out: 4
    boundary_conditions:
      mechanical:
        dot_F: [[1e-4, 0, 0],
                [0, x, 0],
                [0, 0, x]]
        P: [[x, x, x],
            [x, 0, x],
            [x, x, 0]]
""")

tensionX.save(f"damask3/templates/PH_nonlinear_biaxial_TD/tensionX.yaml")
tensionX.save(f"damask3/templates/DB_nonlinear_biaxial_TD/tensionX.yaml")

tensionLoad = '''
              fdot 4.75e-5 0 0  0 5.25e-5 0   0 0 *  stress  * * *   * * *   * * 0  time 60  incs 80 freq 4
              fdot 4.75e-5 0 0  0 5.25e-5 0   0 0 *  stress  * * *   * * *   * * 0  time 1140  incs 80 freq 4
              fdot -4.75e-5 0 0  0 -5.25e-5 0   0 0 *  stress  * * *   * * *   * * 0  time 44  incs 80 freq 4
              fdot 1e-4 0 0  0 * 0   0 0 *  stress  * * *   * 0 *   * * 0  time 78  incs 80 freq 4
              fdot 1e-4 0 0  0 * 0   0 0 *  stress  * * *   * 0 *   * * 0  time 1518  incs 80 freq 4
              '''

# %% [markdown]
# nonlinear_planestrain_RD

# %%
tensionX = damask.Config("""
solver:
  mechanical: spectral_basic

loadstep:
  - discretization:
      t: 60
      N: 80
    f_out: 4
    boundary_conditions:
      mechanical:
        dot_F: [[0, 0, 0],
                [0, 8.55e-5, 0],
                [0, 0, x]]
        P: [[x, x, x],
            [x, x, x],
            [x, x, 0]]
  - discretization:
      t: 880
      N: 80
    f_out: 4
    boundary_conditions:
      mechanical:
        dot_F: [[0, 0, 0],
                [0, 8.55e-5, 0],
                [0, 0, x]]
        P: [[x, x, x],
            [x, x, x],
            [x, x, 0]]
  - discretization:
      t: 37
      N: 80
    f_out: 4
    boundary_conditions:
      mechanical:
        dot_F: [[0, 0, 0],
                [0, -8.55e-5, 0],
                [0, 0, x]]
        P: [[x, x, x],
            [x, x, x],
            [x, x, 0]]
  - discretization:
      t: 71
      N: 80
    f_out: 4
    boundary_conditions:
      mechanical:
        dot_F: [[x, 0, 0],
                [0, 1e-4, 0],
                [0, 0, x]]
        P: [[0, x, x],
            [x, x, x],
            [x, x, 0]]
  - discretization:
      t: 1511
      N: 80
    f_out: 4
    boundary_conditions:
      mechanical:
        dot_F: [[x, 0, 0],
                [0, 1e-4, 0],
                [0, 0, x]]
        P: [[0, x, x],
            [x, x, x],
            [x, x, 0]]
""")

tensionX.save(f"damask3/templates/PH_nonlinear_planestrain_RD/tensionX.yaml")
tensionX.save(f"damask3/templates/DB_nonlinear_planestrain_RD/tensionX.yaml")

tensionLoad = '''
              fdot 0 0 0  0 8.55e-5 0   0 0 *  stress  * * *   * * *   * * 0  time 60  incs 80 freq 4
              fdot 0 0 0  0 8.55e-5 0   0 0 *  stress  * * *   * * *   * * 0  time 880  incs 80 freq 4
              fdot 0 0 0  0 -8.55e-5 0   0 0 *  stress  * * *   * * *   * * 0  time 37  incs 80 freq 4
              fdot * 0 0  0 1e-4 0   0 0 *  stress  0 * *   * * *   * * 0  time 71  incs 80 freq 4
              fdot * 0 0  0 1e-4 0   0 0 *  stress  0 * *   * * *   * * 0  time 1511  incs 80 freq 4
              '''

# %% [markdown]
# nonlinear_planestrain_TD

# %%
tensionX = damask.Config("""
solver:
  mechanical: spectral_basic

loadstep:
  - discretization:
      t: 60
      N: 80
    f_out: 4
    boundary_conditions:
      mechanical:
        dot_F: [[0, 0, 0],
                [0, 8.55e-5, 0],
                [0, 0, x]]
        P: [[x, x, x],
            [x, x, x],
            [x, x, 0]]
  - discretization:
      t: 880
      N: 80
    f_out: 4
    boundary_conditions:
      mechanical:
        dot_F: [[0, 0, 0],
                [0, 8.55e-5, 0],
                [0, 0, x]]
        P: [[x, x, x],
            [x, x, x],
            [x, x, 0]]
  - discretization:
      t: 37
      N: 80
    f_out: 4
    boundary_conditions:
      mechanical:
        dot_F: [[0, 0, 0],
                [0, -8.55e-5, 0],
                [0, 0, x]]
        P: [[x, x, x],
            [x, x, x],
            [x, x, 0]]
  - discretization:
      t: 71
      N: 80
    f_out: 4
    boundary_conditions:
      mechanical:
        dot_F: [[1e-4, 0, 0],
                [0, x, 0],
                [0, 0, x]]
        P: [[x, x, x],
            [x, 0, x],
            [x, x, 0]]
  - discretization:
      t: 1511
      N: 80
    f_out: 4
    boundary_conditions:
      mechanical:
        dot_F: [[1e-4, 0, 0],
                [0, x, 0],
                [0, 0, x]]
        P: [[x, x, x],
            [x, 0, x],
            [x, x, 0]]
""")

tensionX.save(f"damask3/templates/PH_nonlinear_planestrain_TD/tensionX.yaml")
tensionX.save(f"damask3/templates/DB_nonlinear_planestrain_TD/tensionX.yaml")

tensionLoad = '''
              fdot 0 0 0  0 8.55e-5 0   0 0 *  stress  * * *   * * *   * * 0  time 60  incs 80 freq 4
              fdot 0 0 0  0 8.55e-5 0   0 0 *  stress  * * *   * * *   * * 0  time 880  incs 80 freq 4
              fdot 0 0 0  0 -8.55e-5 0   0 0 *  stress  * * *   * * *   * * 0  time 37  incs 80 freq 4
              fdot 1e-4 0 0  0 * 0   0 0 *  stress  * * *   * 0 *   * * 0  time 71  incs 80 freq 4
              fdot 1e-4 0 0  0 * 0   0 0 *  stress  * * *   * 0 *   * * 0  time 1511  incs 80 freq 4
              '''

# %% [markdown]
# nonlinear_uniaxial_RD

# %%
tensionX = damask.Config("""
solver:
  mechanical: spectral_basic
loadstep:
  - discretization:
      t: 60
      N: 80
    f_out: 4
    boundary_conditions:
      mechanical:
        dot_F: [[-3.65e-5, 0, 0],
                [0, 9.88e-5, 0],
                [0, 0, x]]
        P: [[x, x, x],
            [x, x, x],
            [x, x, 0]]
  - discretization:
      t: 542
      N: 80
    f_out: 4
    boundary_conditions:
      mechanical:
        dot_F: [[-3.65e-5, 0, 0],
                [0, 9.88e-5, 0],
                [0, 0, x]]
        P: [[x, x, x],
            [x, x, x],
            [x, x, 0]]
  - discretization:
      t: 26.2
      N: 80
    f_out: 4
    boundary_conditions:
      mechanical:
        dot_F: [[x, 0, 0],
                [0, -9.88e-5, 0],
                [0, 0, x]]
        P: [[0, x, x],
            [x, x, x],
            [x, x, 0]]
  - discretization:
      t: 60.2
      N: 80
    f_out: 4
    boundary_conditions:
      mechanical:
        dot_F: [[x, 0, 0],
                [0, 1e-4, 0],
                [0, 0, x]]
        P: [[0, x, x],
            [x, x, x],
            [x, x, 0]]
  - discretization:
      t: 1500.2
      N: 80
    f_out: 4
    boundary_conditions:
      mechanical:
        dot_F: [[x, 0, 0],
                [0, 1e-4, 0],
                [0, 0, x]]
        P: [[0, x, x],
            [x, x, x],
            [x, x, 0]]
""")

tensionX.save(f"damask3/templates/PH_nonlinear_uniaxial_RD/tensionX.yaml")
tensionX.save(f"damask3/templates/DB_nonlinear_uniaxial_RD/tensionX.yaml")

tensionLoad = '''
              fdot -3.65e-5 0 0  0 9.88e-5 0   0 0 *  stress  * * *   * * *   * * 0  time 60  incs 80 freq 4
              fdot -3.65e-5 0 0  0 9.88e-5 0   0 0 *  stress  * * *   * * *   * * 0  time 542  incs 80 freq 4
              fdot * 0 0  0 -9.88e-5 0   0 0 *  stress  0 * *   * * *   * * 0  time 26.2  incs 80 freq 4
              fdot * 0 0  0 1e-4 0   0 0 *  stress  0 * *   * * *   * * 0  time 60.2  incs 80 freq 4
              fdot * 0 0  0 1e-4 0   0 0 *  stress  0 * *   * * *   * * 0  time 1500.2  incs 80 freq 4
              '''

# %% [markdown]
# nonlinear_uniaxial_TD

# %%
tensionX = damask.Config("""
solver:
  mechanical: spectral_basic
loadstep:
  - discretization:
      t: 60
      N: 80
    f_out: 4
    boundary_conditions:
      mechanical:
        dot_F: [[-3.65e-5, 0, 0],
                [0, 9.88e-5, 0],
                [0, 0, x]]
        P: [[x, x, x],
            [x, x, x],
            [x, x, 0]]
  - discretization:
      t: 542
      N: 80
    f_out: 4
    boundary_conditions:
      mechanical:
        dot_F: [[-3.65e-5, 0, 0],
                [0, 9.88e-5, 0],
                [0, 0, x]]
        P: [[x, x, x],
            [x, x, x],
            [x, x, 0]]
  - discretization:
      t: 26.2
      N: 80
    f_out: 4
    boundary_conditions:
      mechanical:
        dot_F: [[x, 0, 0],
                [0, -9.88e-5, 0],
                [0, 0, x]]
        P: [[0, x, x],
            [x, x, x],
            [x, x, 0]]
  - discretization:
      t: 60.2
      N: 80
    f_out: 4
    boundary_conditions:
      mechanical:
        dot_F: [[1e-4, 0, 0],
                [0, x, 0],
                [0, 0, x]]
        P: [[x, x, x],
            [x, 0, x],
            [x, x, 0]]
  - discretization:
      t: 1500.2
      N: 80
    f_out: 4
    boundary_conditions:
      mechanical:
        dot_F: [[1e-4, 0, 0],
                [0, x, 0],
                [0, 0, x]]
        P: [[x, x, x],
            [x, 0, x],
            [x, x, 0]]
""")

tensionX.save(f"damask3/templates/PH_nonlinear_uniaxial_TD/tensionX.yaml")
tensionX.save(f"damask3/templates/DB_nonlinear_uniaxial_TD/tensionX.yaml")

tensionLoad = '''
              fdot -3.65e-5 0 0  0 9.88e-5 0   0 0 *  stress  * * *   * * *   * * 0  time 60  incs 80 freq 4
              fdot -3.65e-5 0 0  0 9.88e-5 0   0 0 *  stress  * * *   * * *   * * 0  time 542  incs 80 freq 4
              fdot * 0 0  0 -9.88e-5 0   0 0 *  stress  0 * *   * * *   * * 0  time 26.2  incs 80 freq 4
              fdot 1e-4 0 0  0 * 0   0 0 *  stress  * * *   * 0 *   * * 0  time 60.2  incs 80 freq 4
              fdot 1e-4 0 0  0 * 0   0 0 *  stress  * * *   * 0 *   * * 0  time 1500.2  incs 80 freq 4
              '''
